# %% [markdown]
# ## MACD strategy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import matplotlib.ticker as mticker

# %%
path = "data/round_1"


def get_prices(round: int, day: int):

    path = f"data/round_{round}/prices_round_{round}_day_{day}.csv"

    return pd.read_csv(path, sep=";")


def get_trades(round: int, day: int):

    path = f"data/round_{round}/trades_round_{round}_day_{day}.csv"

    return pd.read_csv(path, sep=";")

prices = get_prices(1, -1)
trades = get_trades(1, -1)

def calculate_MACD(
    data: pd.DataFrame,
    price_col: str,
    short_window: int,
    long_window: int,
    smoothing_window: int,
    min_periods: int,
):

    # Calculate the 12-period EMA

    ema_short = data[price_col].ewm(span=short_window, adjust=False).mean()

    ema_long = data[price_col].ewm(span=long_window, adjust=False).mean()

    macd = ema_short - ema_long

    signal = macd.ewm(span=smoothing_window, adjust=False).mean()

    macd.iloc[:min_periods] = np.nan

    signal.iloc[:min_periods] = np.nan

    return macd, signal, ema_short, ema_long



def plot_MACD(prices: pd.DataFrame, macd, signal, ema_short, ema_long):
    fig = plt.figure(figsize=(25, 10))

    gs = GridSpec(2, 1, height_ratios=[2, 1.5], figure=fig)

    price_ax = plt.subplot(gs[0])

    macd_ax = plt.subplot(gs[1])

    price_ax.plot(prices["timestamp"], prices["mid_price"])
    price_ax.plot(prices["timestamp"], ema_short, label="Short EMA", color="green")
    price_ax.plot(prices["timestamp"], ema_long, label="Long EMA", color="red")
    price_ax.legend()

    macd_ax.plot(macd, color="red", label="MACD")
    macd_ax.plot(signal, color="green", label="Signal")
    macd_ax.legend()

    plt.show()

def analyze_product_MACD(prices, product_name, short_window, long_window, smoothing_window):
    # Sort the overall prices DataFrame
    prices.sort_values(["product", "timestamp"], inplace=True)
    
    # Filter for the specific product and sort by timestamp
    product_data = prices[prices["product"] == product_name].sort_values("timestamp")
    
    # Calculate MACD components
    macd, signal, ema_short, ema_long = calculate_MACD(
        product_data, "mid_price", short_window, long_window, smoothing_window, 50
    )
    
    # Plot MACD
    plot_MACD(product_data, macd, signal, ema_short, ema_long)
    
    return macd, signal, ema_short, ema_long, product_data  # <<< ADD product_data here

def generate_MACD_signals(product_data, ema_short, ema_long):
    # Generate position: long (1) if ema_short > ema_long, short (-1) otherwise
    product_data["position"] = np.where(ema_short > ema_long, 1, -1)
    
    # Calculate daily returns
    product_data["ret"] = product_data["mid_price"].pct_change()
    
    # Calculate strategy returns
    product_data["strategy_ret"] = product_data["ret"] * product_data["position"].shift(1)
    
    # Calculate cumulative strategy returns
    product_data["cum_strategy_ret"] = (1 + product_data["strategy_ret"]).cumprod()
    
    # Identify entry and exit points
    product_data["is_entry_point"] = (product_data["position"] == 1) & (product_data["position"].shift(1) == -1)
    product_data["is_exit_point"] = (product_data["position"] == -1) & (product_data["position"].shift(1) == 1)
    
    return product_data
def plot_trades(data: pd.DataFrame, from_timestamp: int):
    fig, ax = plt.subplots(figsize=(22, 5))

    data = data[data["timestamp"] > from_timestamp].copy()

    ax.plot(data["timestamp"], data["mid_price"])

    entries = data[data["is_entry_point"]]
    exits = data[data["is_exit_point"]]

    for i, trade_series in enumerate([entries, exits]):
        color = "green" if i == 0 else "red"
        label = "Open" if i == 0 else "Close" + " Trade"
        ax.scatter(
            trade_series["timestamp"],
            trade_series["mid_price"],
            color=color,
            label=label,
            zorder=i + 2,
        )

    ax.legend()
    ax.set_title("Trading Starfruit using MACD - Trades")
    ax.set_xlabel("Timestamp")
    ax.set_ylabel("Price")

# %%
SHORT_WINDOW = 75
LONG_WINDOW = 603
SMOOTHING_WINDOW = 100

macd, signal, ema_short, ema_long, squid_ink_data = analyze_product_MACD(
    prices, "SQUID_INK", SHORT_WINDOW, LONG_WINDOW, SMOOTHING_WINDOW
)

SQUID_INK = generate_MACD_signals(squid_ink_data, ema_short, ema_long)
plot_trades(SQUID_INK, 0)

# %%
equity_curve = 1000 * SQUID_INK["cum_strategy_ret"]

plt.plot(SQUID_INK["timestamp"], equity_curve)
plt.title("MACD Long/Short Strategy (starting balance 1000)")
plt.xlabel("Timestamp")
plt.ylabel("Equity")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Backtest

# %%
pip install optuna
# Out:
# Collecting optuna
#   Using cached optuna-4.2.1-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.15.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Using cached colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /Users/tommasomarrucci/coding-project/.pixi/envs/default/lib/python3.11/site-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/tommasomarrucci/coding-project/.pixi/envs/default/lib/python3.11/site-packages (from optuna) (24.2)
# Collecting sqlalchemy>=1.4.2 (from optuna)
#   Downloading sqlalchemy-2.0.40-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Requirement already satisfied: tqdm in /Users/tommasomarrucci/coding-project/.pixi/envs/default/lib/python3.11/site-packages (from optuna) (4.67.0)
# Requirement already satisfied: PyYAML in /Users/tommasomarrucci/coding-project/.pixi/envs/default/lib/python3.11/site-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.9-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.12 in /Users/tommasomarrucci/coding-project/.pixi/envs/default/lib/python3.11/site-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Collecting MarkupSafe>=0.9.2 (from Mako->alembic>=1.5.0->optuna)
#   Downloading MarkupSafe-3.0.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Using cached optuna-4.2.1-py3-none-any.whl (383 kB)
# Downloading alembic-1.15.2-py3-none-any.whl (231 kB)
# Downloading sqlalchemy-2.0.40-cp311-cp311-macosx_11_0_arm64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 9.2 MB/s eta 0:00:00a 0:00:01
# Using cached colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.9-py3-none-any.whl (78 kB)
# Downloading MarkupSafe-3.0.2-cp311-cp311-macosx_11_0_arm64.whl (12 kB)
# Installing collected packages: sqlalchemy, MarkupSafe, colorlog, Mako, alembic, optuna
# Successfully installed Mako-1.3.9 MarkupSafe-3.0.2 alembic-1.15.2 colorlog-6.9.0 optuna-4.2.1 sqlalchemy-2.0.40
# Note: you may need to restart the kernel to use updated packages.

# %%
import optuna

def objective(trial):
    short_window = trial.suggest_int('short_window', 5, 100)
    long_window = trial.suggest_int('long_window', short_window + 10, 1000)
    smoothing_window = trial.suggest_int('smoothing_window', 50, 150)

    macd, signal, ema_short, ema_long = calculate_MACD(
        new_prices, "mid_price", short_window, long_window, smoothing_window, 50
    )
    temp_data = new_prices.copy()
    temp_data = generate_MACD_signals(temp_data, ema_short, ema_long)

    final_equity = temp_data["cum_strategy_ret"].iloc[-1]
    return final_equity

study = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler())
study.optimize(objective, n_trials=1000)

# Get best parameters
best_params = study.best_params
print("Best Parameters:", best_params)
print(f"Final Equity Multiplier: {study.best_value:.2f}x")

# Final backtest
macd, signal, ema_short, ema_long = calculate_MACD(
    new_prices, "mid_price", best_short_window, best_long_window, 100, 50
)
final_strategy = new_prices.copy()
final_strategy = generate_MACD_signals(final_strategy, ema_short, ema_long)

# Plot
plot_trades(final_strategy, 0)

equity_curve = 1000 * final_strategy["cum_strategy_ret"]

plt.figure(figsize=(22, 6))
plt.plot(final_strategy["timestamp"], equity_curve)
plt.title(f"Optimized MACD Strategy Equity Curve (Short={best_short_window}, Long={best_long_window})")
plt.xlabel("Timestamp")
plt.ylabel("Equity (Starting Balance 1000)")
plt.grid(True)
plt.show()
# Out:
# [I 2025-04-07 21:12:58,302] A new study created in memory with name: no-name-ba2b889a-8df9-4697-b8bb-a76e93737ce7
# [I 2025-04-07 21:12:58,321] Trial 0 finished with value: 0.9438409405340807 and parameters: {'short_window': 26, 'long_window': 623, 'smoothing_window': 124}. Best is trial 0 with value: 0.9438409405340807.
# [I 2025-04-07 21:12:58,323] Trial 1 finished with value: 0.9809986423317858 and parameters: {'short_window': 73, 'long_window': 888, 'smoothing_window': 101}. Best is trial 1 with value: 0.9809986423317858.
# [I 2025-04-07 21:12:58,328] Trial 2 finished with value: 0.9561890170714141 and parameters: {'short_window': 11, 'long_window': 264, 'smoothing_window': 66}. Best is trial 1 with value: 0.9809986423317858.
# [I 2025-04-07 21:12:58,330] Trial 3 finished with value: 0.9714096768695291 and parameters: {'short_window': 56, 'long_window': 837, 'smoothing_window': 124}. Best is trial 1 with value: 0.9809986423317858.
# [I 2025-04-07 21:12:58,332] Trial 4 finished with value: 0.9494293034669223 and parameters: {'short_window': 54, 'long_window': 292, 'smoothing_window': 88}. Best is trial 1 with value: 0.9809986423317858.
# [I 2025-04-07 21:12:58,334] Trial 5 finished with value: 0.957793822224079 and parameters: {'short_window': 15, 'long_window': 936, 'smoothing_window': 118}. Best is trial 1 with value: 0.9809986423317858.
# [I 2025-04-07 21:12:58,335] Trial 6 finished with value: 0.9644903198362091 and parameters: {'short_window': 45, 'long_window': 229, 'smoothing_window': 97}. Best is trial 1 with value: 0.9809986423317858.
# [I 2025-04-07 21:12:58,337] Trial 7 finished with value: 0.9677035241313887 and parameters: {'short_window': 28, 'long_window': 873, 'smoothing_window': 125}. Best is trial 1 with value: 0.9809986423317858.
# [I 2025-04-07 21:12:58,339] Trial 8 finished with value: 0.9960604304255098 and parameters: {'short_window': 91, 'long_window': 747, 'smoothing_window': 58}. Best is trial 8 with value: 0.9960604304255098.
# [I 2025-04-07 21:12:58,341] Trial 9 finished with value: 0.9639738696061055 and parameters: {'short_window': 10, 'long_window': 253, 'smoothing_window': 58}. Best is trial 8 with value: 0.9960604304255098.
# [I 2025-04-07 21:12:58,350] Trial 10 finished with value: 0.9966019075041972 and parameters: {'short_window': 99, 'long_window': 603, 'smoothing_window': 75}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,357] Trial 11 finished with value: 0.9966019075041972 and parameters: {'short_window': 100, 'long_window': 599, 'smoothing_window': 73}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,364] Trial 12 finished with value: 0.9788876479062855 and parameters: {'short_window': 100, 'long_window': 478, 'smoothing_window': 76}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,371] Trial 13 finished with value: 0.9825422121398092 and parameters: {'short_window': 81, 'long_window': 482, 'smoothing_window': 148}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,378] Trial 14 finished with value: 0.9714312553665639 and parameters: {'short_window': 76, 'long_window': 633, 'smoothing_window': 76}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,386] Trial 15 finished with value: 0.9703963942970951 and parameters: {'short_window': 100, 'long_window': 447, 'smoothing_window': 80}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,393] Trial 16 finished with value: 0.9783279790362008 and parameters: {'short_window': 67, 'long_window': 688, 'smoothing_window': 50}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,401] Trial 17 finished with value: 0.9640157833097623 and parameters: {'short_window': 89, 'long_window': 385, 'smoothing_window': 101}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,409] Trial 18 finished with value: 0.9756860870352921 and parameters: {'short_window': 87, 'long_window': 551, 'smoothing_window': 67}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,416] Trial 19 finished with value: 0.9708205509872065 and parameters: {'short_window': 65, 'long_window': 86, 'smoothing_window': 91}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,424] Trial 20 finished with value: 0.9767161356012094 and parameters: {'short_window': 40, 'long_window': 766, 'smoothing_window': 110}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,432] Trial 21 finished with value: 0.9960604304255098 and parameters: {'short_window': 91, 'long_window': 742, 'smoothing_window': 50}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,439] Trial 22 finished with value: 0.993347109438188 and parameters: {'short_window': 94, 'long_window': 995, 'smoothing_window': 64}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,448] Trial 23 finished with value: 0.9767405978021515 and parameters: {'short_window': 81, 'long_window': 582, 'smoothing_window': 79}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,455] Trial 24 finished with value: 0.9949745100870802 and parameters: {'short_window': 99, 'long_window': 768, 'smoothing_window': 60}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,463] Trial 25 finished with value: 0.9868934713484948 and parameters: {'short_window': 84, 'long_window': 728, 'smoothing_window': 71}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,470] Trial 26 finished with value: 0.9895815373485415 and parameters: {'short_window': 91, 'long_window': 652, 'smoothing_window': 88}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,478] Trial 27 finished with value: 0.97454070125318 and parameters: {'short_window': 70, 'long_window': 547, 'smoothing_window': 60}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,485] Trial 28 finished with value: 0.9629547034685169 and parameters: {'short_window': 61, 'long_window': 350, 'smoothing_window': 56}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,493] Trial 29 finished with value: 0.9852870101692323 and parameters: {'short_window': 94, 'long_window': 602, 'smoothing_window': 72}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,501] Trial 30 finished with value: 0.9868892295349952 and parameters: {'short_window': 75, 'long_window': 819, 'smoothing_window': 80}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,509] Trial 31 finished with value: 0.9944306615183499 and parameters: {'short_window': 93, 'long_window': 708, 'smoothing_window': 50}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,517] Trial 32 finished with value: 0.9799555991717689 and parameters: {'short_window': 84, 'long_window': 663, 'smoothing_window': 53}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,526] Trial 33 finished with value: 0.9949745100870802 and parameters: {'short_window': 95, 'long_window': 811, 'smoothing_window': 63}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,534] Trial 34 finished with value: 0.9868892295349952 and parameters: {'short_window': 80, 'long_window': 746, 'smoothing_window': 68}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,543] Trial 35 finished with value: 0.9799404032003568 and parameters: {'short_window': 88, 'long_window': 527, 'smoothing_window': 55}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,551] Trial 36 finished with value: 0.9966019075041972 and parameters: {'short_window': 97, 'long_window': 603, 'smoothing_window': 86}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,560] Trial 37 finished with value: 0.9966019075041972 and parameters: {'short_window': 100, 'long_window': 603, 'smoothing_window': 83}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,568] Trial 38 finished with value: 0.9966019075041972 and parameters: {'short_window': 100, 'long_window': 605, 'smoothing_window': 86}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,577] Trial 39 finished with value: 0.9723954350225268 and parameters: {'short_window': 22, 'long_window': 403, 'smoothing_window': 96}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,584] Trial 40 finished with value: 0.9655237938341298 and parameters: {'short_window': 44, 'long_window': 481, 'smoothing_window': 104}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,593] Trial 41 finished with value: 0.9966019075041972 and parameters: {'short_window': 98, 'long_window': 606, 'smoothing_window': 85}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,600] Trial 42 finished with value: 0.9863547825996506 and parameters: {'short_window': 96, 'long_window': 579, 'smoothing_window': 85}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,609] Trial 43 finished with value: 0.9777782811946619 and parameters: {'short_window': 86, 'long_window': 522, 'smoothing_window': 93}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,617] Trial 44 finished with value: 0.9960604304255098 and parameters: {'short_window': 100, 'long_window': 673, 'smoothing_window': 85}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,627] Trial 45 finished with value: 0.9966019075041972 and parameters: {'short_window': 96, 'long_window': 627, 'smoothing_window': 74}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,635] Trial 46 finished with value: 0.9597992180147763 and parameters: {'short_window': 35, 'long_window': 564, 'smoothing_window': 81}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,643] Trial 47 finished with value: 0.9825349429565199 and parameters: {'short_window': 78, 'long_window': 503, 'smoothing_window': 107}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,651] Trial 48 finished with value: 0.983089802400614 and parameters: {'short_window': 100, 'long_window': 426, 'smoothing_window': 97}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,660] Trial 49 finished with value: 0.9799453573960583 and parameters: {'short_window': 89, 'long_window': 630, 'smoothing_window': 91}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,668] Trial 50 finished with value: 0.9782890137036914 and parameters: {'short_window': 84, 'long_window': 452, 'smoothing_window': 113}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,677] Trial 51 finished with value: 0.9966019075041972 and parameters: {'short_window': 97, 'long_window': 606, 'smoothing_window': 84}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,685] Trial 52 finished with value: 0.9944306615183499 and parameters: {'short_window': 92, 'long_window': 687, 'smoothing_window': 77}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,693] Trial 53 finished with value: 0.9966019075041972 and parameters: {'short_window': 100, 'long_window': 596, 'smoothing_window': 70}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,702] Trial 54 finished with value: 0.9799538511009666 and parameters: {'short_window': 96, 'long_window': 553, 'smoothing_window': 88}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,710] Trial 55 finished with value: 0.9567785381452839 and parameters: {'short_window': 5, 'long_window': 652, 'smoothing_window': 82}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,719] Trial 56 finished with value: 0.9798712163281135 and parameters: {'short_window': 50, 'long_window': 705, 'smoothing_window': 132}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,729] Trial 57 finished with value: 0.982060912593271 and parameters: {'short_window': 90, 'long_window': 498, 'smoothing_window': 75}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,738] Trial 58 finished with value: 0.9966019075041972 and parameters: {'short_window': 97, 'long_window': 621, 'smoothing_window': 88}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,747] Trial 59 finished with value: 0.982060912593271 and parameters: {'short_window': 86, 'long_window': 528, 'smoothing_window': 97}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,756] Trial 60 finished with value: 0.946314317003942 and parameters: {'short_window': 92, 'long_window': 191, 'smoothing_window': 77}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,764] Trial 61 finished with value: 0.9966019075041972 and parameters: {'short_window': 97, 'long_window': 637, 'smoothing_window': 73}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,774] Trial 62 finished with value: 0.9799453573960583 and parameters: {'short_window': 94, 'long_window': 584, 'smoothing_window': 74}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,782] Trial 63 finished with value: 0.9966019075041972 and parameters: {'short_window': 97, 'long_window': 634, 'smoothing_window': 66}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,791] Trial 64 finished with value: 0.9960604304255098 and parameters: {'short_window': 89, 'long_window': 785, 'smoothing_window': 93}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,800] Trial 65 finished with value: 0.9960604304255098 and parameters: {'short_window': 100, 'long_window': 706, 'smoothing_window': 78}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,809] Trial 66 finished with value: 0.9852870101692323 and parameters: {'short_window': 93, 'long_window': 611, 'smoothing_window': 83}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,817] Trial 67 finished with value: 0.9777782811946619 and parameters: {'short_window': 81, 'long_window': 557, 'smoothing_window': 69}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,827] Trial 68 finished with value: 0.9944306615183499 and parameters: {'short_window': 97, 'long_window': 670, 'smoothing_window': 150}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,835] Trial 69 finished with value: 0.9793342069559186 and parameters: {'short_window': 94, 'long_window': 455, 'smoothing_window': 87}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,845] Trial 70 finished with value: 0.9756860870352921 and parameters: {'short_window': 84, 'long_window': 573, 'smoothing_window': 64}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,853] Trial 71 finished with value: 0.9966019075041972 and parameters: {'short_window': 98, 'long_window': 606, 'smoothing_window': 83}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,863] Trial 72 finished with value: 0.9885060409422275 and parameters: {'short_window': 95, 'long_window': 604, 'smoothing_window': 91}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,872] Trial 73 finished with value: 0.987428517958063 and parameters: {'short_window': 91, 'long_window': 647, 'smoothing_window': 86}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,881] Trial 74 finished with value: 0.9944306615183499 and parameters: {'short_window': 87, 'long_window': 723, 'smoothing_window': 79}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,890] Trial 75 finished with value: 0.977211374531364 and parameters: {'short_window': 59, 'long_window': 515, 'smoothing_window': 101}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,899] Trial 76 finished with value: 0.9799538511009666 and parameters: {'short_window': 98, 'long_window': 534, 'smoothing_window': 72}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,923] Trial 77 finished with value: 0.9944306615183499 and parameters: {'short_window': 95, 'long_window': 685, 'smoothing_window': 84}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,933] Trial 78 finished with value: 0.9966019075041972 and parameters: {'short_window': 100, 'long_window': 616, 'smoothing_window': 94}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,942] Trial 79 finished with value: 0.9846886951897396 and parameters: {'short_window': 71, 'long_window': 565, 'smoothing_window': 81}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,951] Trial 80 finished with value: 0.9788866538767906 and parameters: {'short_window': 91, 'long_window': 588, 'smoothing_window': 61}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,961] Trial 81 finished with value: 0.9966019075041972 and parameters: {'short_window': 100, 'long_window': 595, 'smoothing_window': 70}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,971] Trial 82 finished with value: 0.9944306615183499 and parameters: {'short_window': 98, 'long_window': 668, 'smoothing_window': 75}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,981] Trial 83 finished with value: 0.9966019075041972 and parameters: {'short_window': 93, 'long_window': 646, 'smoothing_window': 67}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:58,991] Trial 84 finished with value: 0.9799451958112351 and parameters: {'short_window': 96, 'long_window': 535, 'smoothing_window': 89}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,000] Trial 85 finished with value: 0.9966019075041972 and parameters: {'short_window': 100, 'long_window': 586, 'smoothing_window': 70}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,010] Trial 86 finished with value: 0.9826169641501364 and parameters: {'short_window': 89, 'long_window': 623, 'smoothing_window': 79}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,019] Trial 87 finished with value: 0.9788824378527717 and parameters: {'short_window': 95, 'long_window': 498, 'smoothing_window': 74}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,029] Trial 88 finished with value: 0.9788764232729092 and parameters: {'short_window': 98, 'long_window': 550, 'smoothing_window': 90}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,038] Trial 89 finished with value: 0.9740156879862428 and parameters: {'short_window': 24, 'long_window': 468, 'smoothing_window': 143}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,048] Trial 90 finished with value: 0.9949745100870802 and parameters: {'short_window': 87, 'long_window': 922, 'smoothing_window': 77}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,058] Trial 91 finished with value: 0.9966019075041972 and parameters: {'short_window': 97, 'long_window': 626, 'smoothing_window': 86}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,067] Trial 92 finished with value: 0.9966019075041972 and parameters: {'short_window': 92, 'long_window': 661, 'smoothing_window': 80}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,077] Trial 93 finished with value: 0.9966019075041972 and parameters: {'short_window': 98, 'long_window': 607, 'smoothing_window': 84}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,087] Trial 94 finished with value: 0.9836693625544578 and parameters: {'short_window': 95, 'long_window': 584, 'smoothing_window': 95}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,097] Trial 95 finished with value: 0.9895783186224444 and parameters: {'short_window': 100, 'long_window': 566, 'smoothing_window': 72}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,108] Trial 96 finished with value: 0.9826044972093372 and parameters: {'short_window': 91, 'long_window': 627, 'smoothing_window': 82}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,117] Trial 97 finished with value: 0.9944306615183499 and parameters: {'short_window': 93, 'long_window': 689, 'smoothing_window': 87}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,128] Trial 98 finished with value: 0.966106853230011 and parameters: {'short_window': 30, 'long_window': 762, 'smoothing_window': 92}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,137] Trial 99 finished with value: 0.9724509106089348 and parameters: {'short_window': 18, 'long_window': 541, 'smoothing_window': 100}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,148] Trial 100 finished with value: 0.9960604304255098 and parameters: {'short_window': 96, 'long_window': 725, 'smoothing_window': 75}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,159] Trial 101 finished with value: 0.9944306615183499 and parameters: {'short_window': 98, 'long_window': 641, 'smoothing_window': 65}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,169] Trial 102 finished with value: 0.9960585040649917 and parameters: {'short_window': 97, 'long_window': 599, 'smoothing_window': 73}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,182] Trial 103 finished with value: 0.9966019075041972 and parameters: {'short_window': 94, 'long_window': 641, 'smoothing_window': 77}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,201] Trial 104 finished with value: 0.9966019075041972 and parameters: {'short_window': 90, 'long_window': 680, 'smoothing_window': 69}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,233] Trial 105 finished with value: 0.9966019075041972 and parameters: {'short_window': 96, 'long_window': 619, 'smoothing_window': 89}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,243] Trial 106 finished with value: 0.9831405607648254 and parameters: {'short_window': 85, 'long_window': 703, 'smoothing_window': 81}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,253] Trial 107 finished with value: 0.9944306615183499 and parameters: {'short_window': 99, 'long_window': 658, 'smoothing_window': 85}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,264] Trial 108 finished with value: 0.9799538511009666 and parameters: {'short_window': 94, 'long_window': 569, 'smoothing_window': 71}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,274] Trial 109 finished with value: 0.9809571864708297 and parameters: {'short_window': 88, 'long_window': 508, 'smoothing_window': 79}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,284] Trial 110 finished with value: 0.9966019075041972 and parameters: {'short_window': 100, 'long_window': 602, 'smoothing_window': 67}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,295] Trial 111 finished with value: 0.9966019075041972 and parameters: {'short_window': 97, 'long_window': 635, 'smoothing_window': 63}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,305] Trial 112 finished with value: 0.9966019075041972 and parameters: {'short_window': 98, 'long_window': 623, 'smoothing_window': 57}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,315] Trial 113 finished with value: 0.9788866538767906 and parameters: {'short_window': 92, 'long_window': 574, 'smoothing_window': 61}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,326] Trial 114 finished with value: 0.9863553614949783 and parameters: {'short_window': 96, 'long_window': 592, 'smoothing_window': 73}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,336] Trial 115 finished with value: 0.9966019075041972 and parameters: {'short_window': 93, 'long_window': 655, 'smoothing_window': 76}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,346] Trial 116 finished with value: 0.9724152644957539 and parameters: {'short_window': 49, 'long_window': 549, 'smoothing_window': 67}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,357] Trial 117 finished with value: 0.9966019075041972 and parameters: {'short_window': 100, 'long_window': 614, 'smoothing_window': 69}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,367] Trial 118 finished with value: 0.9944306615183499 and parameters: {'short_window': 98, 'long_window': 635, 'smoothing_window': 83}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,378] Trial 119 finished with value: 0.9944306615183499 and parameters: {'short_window': 90, 'long_window': 695, 'smoothing_window': 98}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,389] Trial 120 finished with value: 0.9944306615183499 and parameters: {'short_window': 95, 'long_window': 672, 'smoothing_window': 88}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,399] Trial 121 finished with value: 0.9966019075041972 and parameters: {'short_window': 98, 'long_window': 606, 'smoothing_window': 82}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,409] Trial 122 finished with value: 0.9863547825996506 and parameters: {'short_window': 96, 'long_window': 578, 'smoothing_window': 78}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,419] Trial 123 finished with value: 0.9944306615183499 and parameters: {'short_window': 100, 'long_window': 642, 'smoothing_window': 84}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,429] Trial 124 finished with value: 0.9966019075041972 and parameters: {'short_window': 98, 'long_window': 596, 'smoothing_window': 65}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,439] Trial 125 finished with value: 0.9852870101692323 and parameters: {'short_window': 93, 'long_window': 615, 'smoothing_window': 74}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,449] Trial 126 finished with value: 0.9788764232729092 and parameters: {'short_window': 96, 'long_window': 561, 'smoothing_window': 90}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,459] Trial 127 finished with value: 0.9944306615183499 and parameters: {'short_window': 94, 'long_window': 662, 'smoothing_window': 87}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,469] Trial 128 finished with value: 0.9895783186224444 and parameters: {'short_window': 98, 'long_window': 582, 'smoothing_window': 80}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,479] Trial 129 finished with value: 0.9788764232729092 and parameters: {'short_window': 100, 'long_window': 534, 'smoothing_window': 71}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,489] Trial 130 finished with value: 0.9852870101692323 and parameters: {'short_window': 91, 'long_window': 634, 'smoothing_window': 85}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,499] Trial 131 finished with value: 0.9966019075041972 and parameters: {'short_window': 100, 'long_window': 613, 'smoothing_window': 91}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,509] Trial 132 finished with value: 0.9960585040649917 and parameters: {'short_window': 97, 'long_window': 595, 'smoothing_window': 82}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,520] Trial 133 finished with value: 0.9724134541935887 and parameters: {'short_window': 65, 'long_window': 555, 'smoothing_window': 87}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,531] Trial 134 finished with value: 0.9966019075041972 and parameters: {'short_window': 95, 'long_window': 620, 'smoothing_window': 95}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,541] Trial 135 finished with value: 0.9944306615183499 and parameters: {'short_window': 98, 'long_window': 655, 'smoothing_window': 92}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,551] Trial 136 finished with value: 0.9960604304255098 and parameters: {'short_window': 100, 'long_window': 677, 'smoothing_window': 94}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,562] Trial 137 finished with value: 0.9799538511009666 and parameters: {'short_window': 93, 'long_window': 579, 'smoothing_window': 76}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,572] Trial 138 finished with value: 0.9895783186224444 and parameters: {'short_window': 96, 'long_window': 603, 'smoothing_window': 89}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,582] Trial 139 finished with value: 0.9836693625544578 and parameters: {'short_window': 89, 'long_window': 643, 'smoothing_window': 104}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,594] Trial 140 finished with value: 0.9966019075041972 and parameters: {'short_window': 98, 'long_window': 628, 'smoothing_window': 79}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,604] Trial 141 finished with value: 0.9966019075041972 and parameters: {'short_window': 100, 'long_window': 593, 'smoothing_window': 70}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,615] Trial 142 finished with value: 0.9788764232729092 and parameters: {'short_window': 96, 'long_window': 568, 'smoothing_window': 72}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,626] Trial 143 finished with value: 0.9966019075041972 and parameters: {'short_window': 100, 'long_window': 616, 'smoothing_window': 62}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,637] Trial 144 finished with value: 0.9799453573960583 and parameters: {'short_window': 94, 'long_window': 587, 'smoothing_window': 68}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,648] Trial 145 finished with value: 0.9788764232729092 and parameters: {'short_window': 98, 'long_window': 551, 'smoothing_window': 59}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,659] Trial 146 finished with value: 0.9788824378527717 and parameters: {'short_window': 92, 'long_window': 519, 'smoothing_window': 66}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,669] Trial 147 finished with value: 0.9808418530811159 and parameters: {'short_window': 96, 'long_window': 112, 'smoothing_window': 84}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,681] Trial 148 finished with value: 0.9629842367387714 and parameters: {'short_window': 98, 'long_window': 302, 'smoothing_window': 73}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,692] Trial 149 finished with value: 0.9787993697816051 and parameters: {'short_window': 39, 'long_window': 712, 'smoothing_window': 86}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,703] Trial 150 finished with value: 0.9944306615183499 and parameters: {'short_window': 100, 'long_window': 650, 'smoothing_window': 76}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,714] Trial 151 finished with value: 0.9966019075041972 and parameters: {'short_window': 94, 'long_window': 632, 'smoothing_window': 70}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,726] Trial 152 finished with value: 0.9966019075041972 and parameters: {'short_window': 97, 'long_window': 608, 'smoothing_window': 67}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,736] Trial 153 finished with value: 0.9944306615183499 and parameters: {'short_window': 95, 'long_window': 651, 'smoothing_window': 64}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,747] Trial 154 finished with value: 0.9966019075041972 and parameters: {'short_window': 92, 'long_window': 670, 'smoothing_window': 74}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,758] Trial 155 finished with value: 0.9966019075041972 and parameters: {'short_window': 99, 'long_window': 593, 'smoothing_window': 81}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,769] Trial 156 finished with value: 0.9966019075041972 and parameters: {'short_window': 97, 'long_window': 619, 'smoothing_window': 78}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,780] Trial 157 finished with value: 0.9799538511009666 and parameters: {'short_window': 94, 'long_window': 571, 'smoothing_window': 83}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,791] Trial 158 finished with value: 0.9944306615183499 and parameters: {'short_window': 100, 'long_window': 637, 'smoothing_window': 69}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,802] Trial 159 finished with value: 0.9960585040649917 and parameters: {'short_window': 96, 'long_window': 605, 'smoothing_window': 66}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,813] Trial 160 finished with value: 0.9966019075041972 and parameters: {'short_window': 98, 'long_window': 630, 'smoothing_window': 89}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,825] Trial 161 finished with value: 0.9966019075041972 and parameters: {'short_window': 100, 'long_window': 585, 'smoothing_window': 70}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,835] Trial 162 finished with value: 0.9966019075041972 and parameters: {'short_window': 98, 'long_window': 598, 'smoothing_window': 71}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,847] Trial 163 finished with value: 0.9799538511009666 and parameters: {'short_window': 95, 'long_window': 565, 'smoothing_window': 68}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,859] Trial 164 finished with value: 0.9966019075041972 and parameters: {'short_window': 100, 'long_window': 614, 'smoothing_window': 73}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,870] Trial 165 finished with value: 0.9794097167482991 and parameters: {'short_window': 93, 'long_window': 539, 'smoothing_window': 75}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,881] Trial 166 finished with value: 0.9944306615183499 and parameters: {'short_window': 97, 'long_window': 658, 'smoothing_window': 122}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,894] Trial 167 finished with value: 0.9895783186224444 and parameters: {'short_window': 98, 'long_window': 582, 'smoothing_window': 85}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,905] Trial 168 finished with value: 0.987428517958063 and parameters: {'short_window': 91, 'long_window': 646, 'smoothing_window': 80}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,916] Trial 169 finished with value: 0.9944306615183499 and parameters: {'short_window': 95, 'long_window': 678, 'smoothing_window': 98}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,928] Trial 170 finished with value: 0.9944306615183499 and parameters: {'short_window': 100, 'long_window': 621, 'smoothing_window': 63}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,939] Trial 171 finished with value: 0.9966019075041972 and parameters: {'short_window': 97, 'long_window': 631, 'smoothing_window': 87}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,950] Trial 172 finished with value: 0.9960585040649917 and parameters: {'short_window': 96, 'long_window': 605, 'smoothing_window': 92}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,961] Trial 173 finished with value: 0.9960585040649917 and parameters: {'short_window': 98, 'long_window': 593, 'smoothing_window': 86}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,973] Trial 174 finished with value: 0.9944306615183499 and parameters: {'short_window': 100, 'long_window': 625, 'smoothing_window': 84}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,984] Trial 175 finished with value: 0.9799538511009666 and parameters: {'short_window': 93, 'long_window': 574, 'smoothing_window': 82}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:12:59,995] Trial 176 finished with value: 0.9966019075041972 and parameters: {'short_window': 96, 'long_window': 610, 'smoothing_window': 71}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,006] Trial 177 finished with value: 0.9944306615183499 and parameters: {'short_window': 98, 'long_window': 643, 'smoothing_window': 89}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,029] Trial 178 finished with value: 0.9799538511009666 and parameters: {'short_window': 95, 'long_window': 562, 'smoothing_window': 77}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,040] Trial 179 finished with value: 0.9966019075041972 and parameters: {'short_window': 100, 'long_window': 594, 'smoothing_window': 66}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,051] Trial 180 finished with value: 0.9944306615183499 and parameters: {'short_window': 98, 'long_window': 667, 'smoothing_window': 68}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,062] Trial 181 finished with value: 0.9966019075041972 and parameters: {'short_window': 93, 'long_window': 656, 'smoothing_window': 80}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,072] Trial 182 finished with value: 0.9960604304255098 and parameters: {'short_window': 96, 'long_window': 690, 'smoothing_window': 82}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,084] Trial 183 finished with value: 0.9756067056617563 and parameters: {'short_window': 57, 'long_window': 632, 'smoothing_window': 86}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,095] Trial 184 finished with value: 0.9799453573960583 and parameters: {'short_window': 91, 'long_window': 614, 'smoothing_window': 78}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,106] Trial 185 finished with value: 0.9955176184441135 and parameters: {'short_window': 98, 'long_window': 867, 'smoothing_window': 75}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,117] Trial 186 finished with value: 0.9799453573960583 and parameters: {'short_window': 94, 'long_window': 585, 'smoothing_window': 72}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,128] Trial 187 finished with value: 0.9944306615183499 and parameters: {'short_window': 100, 'long_window': 641, 'smoothing_window': 80}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,139] Trial 188 finished with value: 0.9944306615183499 and parameters: {'short_window': 96, 'long_window': 664, 'smoothing_window': 84}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,150] Trial 189 finished with value: 0.9966019075041972 and parameters: {'short_window': 98, 'long_window': 621, 'smoothing_window': 87}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,161] Trial 190 finished with value: 0.9799453573960583 and parameters: {'short_window': 92, 'long_window': 602, 'smoothing_window': 76}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,173] Trial 191 finished with value: 0.9960585040649917 and parameters: {'short_window': 97, 'long_window': 601, 'smoothing_window': 83}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,184] Trial 192 finished with value: 0.9960585040649917 and parameters: {'short_window': 99, 'long_window': 582, 'smoothing_window': 85}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,195] Trial 193 finished with value: 0.9895783186224444 and parameters: {'short_window': 94, 'long_window': 621, 'smoothing_window': 89}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,207] Trial 194 finished with value: 0.9944306615183499 and parameters: {'short_window': 100, 'long_window': 646, 'smoothing_window': 73}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,218] Trial 195 finished with value: 0.9788764232729092 and parameters: {'short_window': 97, 'long_window': 557, 'smoothing_window': 81}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,230] Trial 196 finished with value: 0.9799310650213863 and parameters: {'short_window': 75, 'long_window': 602, 'smoothing_window': 69}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,243] Trial 197 finished with value: 0.9966019075041972 and parameters: {'short_window': 95, 'long_window': 631, 'smoothing_window': 83}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,254] Trial 198 finished with value: 0.9863553614949783 and parameters: {'short_window': 98, 'long_window': 574, 'smoothing_window': 135}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,266] Trial 199 finished with value: 0.9966019075041972 and parameters: {'short_window': 100, 'long_window': 611, 'smoothing_window': 94}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,278] Trial 200 finished with value: 0.9944306615183499 and parameters: {'short_window': 96, 'long_window': 658, 'smoothing_window': 78}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,291] Trial 201 finished with value: 0.993347109438188 and parameters: {'short_window': 94, 'long_window': 989, 'smoothing_window': 74}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,302] Trial 202 finished with value: 0.9944306615183499 and parameters: {'short_window': 98, 'long_window': 641, 'smoothing_window': 77}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,314] Trial 203 finished with value: 0.9901181867722649 and parameters: {'short_window': 94, 'long_window': 624, 'smoothing_window': 71}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,326] Trial 204 finished with value: 0.9890419618101831 and parameters: {'short_window': 97, 'long_window': 589, 'smoothing_window': 87}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,337] Trial 205 finished with value: 0.9901181867722649 and parameters: {'short_window': 89, 'long_window': 679, 'smoothing_window': 79}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,350] Trial 206 finished with value: 0.9966019075041972 and parameters: {'short_window': 100, 'long_window': 608, 'smoothing_window': 85}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,362] Trial 207 finished with value: 0.9901181867722649 and parameters: {'short_window': 92, 'long_window': 643, 'smoothing_window': 91}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,374] Trial 208 finished with value: 0.9966019075041972 and parameters: {'short_window': 96, 'long_window': 626, 'smoothing_window': 82}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,385] Trial 209 finished with value: 0.9960585040649917 and parameters: {'short_window': 98, 'long_window': 588, 'smoothing_window': 75}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,397] Trial 210 finished with value: 0.9944306615183499 and parameters: {'short_window': 99, 'long_window': 654, 'smoothing_window': 70}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,409] Trial 211 finished with value: 0.9944306615183499 and parameters: {'short_window': 91, 'long_window': 688, 'smoothing_window': 66}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,420] Trial 212 finished with value: 0.9645989594019568 and parameters: {'short_window': 12, 'long_window': 696, 'smoothing_window': 70}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,433] Trial 213 finished with value: 0.9944306615183499 and parameters: {'short_window': 95, 'long_window': 665, 'smoothing_window': 68}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,445] Trial 214 finished with value: 0.9852870101692323 and parameters: {'short_window': 93, 'long_window': 615, 'smoothing_window': 73}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,456] Trial 215 finished with value: 0.9966019075041972 and parameters: {'short_window': 97, 'long_window': 636, 'smoothing_window': 72}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,468] Trial 216 finished with value: 0.9799538511009666 and parameters: {'short_window': 90, 'long_window': 601, 'smoothing_window': 65}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,479] Trial 217 finished with value: 0.9730078275959931 and parameters: {'short_window': 69, 'long_window': 723, 'smoothing_window': 88}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,491] Trial 218 finished with value: 0.9960585040649917 and parameters: {'short_window': 100, 'long_window': 570, 'smoothing_window': 68}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,502] Trial 219 finished with value: 0.9966019075041972 and parameters: {'short_window': 96, 'long_window': 618, 'smoothing_window': 84}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,515] Trial 220 finished with value: 0.9944306615183499 and parameters: {'short_window': 98, 'long_window': 643, 'smoothing_window': 81}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,529] Trial 221 finished with value: 0.9852870101692323 and parameters: {'short_window': 95, 'long_window': 594, 'smoothing_window': 88}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,545] Trial 222 finished with value: 0.9966019075041972 and parameters: {'short_window': 98, 'long_window': 626, 'smoothing_window': 90}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,558] Trial 223 finished with value: 0.9960585040649917 and parameters: {'short_window': 96, 'long_window': 607, 'smoothing_window': 86}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,575] Trial 224 finished with value: 0.9960604304255098 and parameters: {'short_window': 100, 'long_window': 669, 'smoothing_window': 84}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,602] Trial 225 finished with value: 0.9890419618101831 and parameters: {'short_window': 94, 'long_window': 618, 'smoothing_window': 77}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,632] Trial 226 finished with value: 0.9890419618101831 and parameters: {'short_window': 98, 'long_window': 581, 'smoothing_window': 89}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,645] Trial 227 finished with value: 0.9966019075041972 and parameters: {'short_window': 96, 'long_window': 639, 'smoothing_window': 86}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:00,668] Trial 228 finished with value: 0.9799453573960583 and parameters: {'short_window': 93, 'long_window': 597, 'smoothing_window': 93}. Best is trial 10 with value: 0.9966019075041972.
# ...
# [I 2025-04-07 21:13:14,932] Trial 925 finished with value: 0.9890419618101831 and parameters: {'short_window': 96, 'long_window': 600, 'smoothing_window': 72}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:14,958] Trial 926 finished with value: 0.9944306615183499 and parameters: {'short_window': 100, 'long_window': 620, 'smoothing_window': 87}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:14,983] Trial 927 finished with value: 0.9960585040649917 and parameters: {'short_window': 98, 'long_window': 588, 'smoothing_window': 84}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,010] Trial 928 finished with value: 0.9966019075041972 and parameters: {'short_window': 94, 'long_window': 643, 'smoothing_window': 68}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,035] Trial 929 finished with value: 0.9960604304255098 and parameters: {'short_window': 97, 'long_window': 694, 'smoothing_window': 135}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,061] Trial 930 finished with value: 0.9966019075041972 and parameters: {'short_window': 100, 'long_window': 607, 'smoothing_window': 65}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,098] Trial 931 finished with value: 0.9799538511009666 and parameters: {'short_window': 95, 'long_window': 560, 'smoothing_window': 90}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,124] Trial 932 finished with value: 0.9966019075041972 and parameters: {'short_window': 98, 'long_window': 630, 'smoothing_window': 71}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,149] Trial 933 finished with value: 0.9966019075041972 and parameters: {'short_window': 92, 'long_window': 663, 'smoothing_window': 77}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,175] Trial 934 finished with value: 0.9782582426551185 and parameters: {'short_window': 54, 'long_window': 647, 'smoothing_window': 62}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,201] Trial 935 finished with value: 0.9863547825996506 and parameters: {'short_window': 96, 'long_window': 579, 'smoothing_window': 86}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,227] Trial 936 finished with value: 0.9788866538767906 and parameters: {'short_window': 87, 'long_window': 618, 'smoothing_window': 82}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,253] Trial 937 finished with value: 0.9966019075041972 and parameters: {'short_window': 99, 'long_window': 598, 'smoothing_window': 73}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,279] Trial 938 finished with value: 0.9820639436229562 and parameters: {'short_window': 93, 'long_window': 546, 'smoothing_window': 69}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,305] Trial 939 finished with value: 0.9966019075041972 and parameters: {'short_window': 97, 'long_window': 635, 'smoothing_window': 85}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,346] Trial 940 finished with value: 0.9966019075041972 and parameters: {'short_window': 100, 'long_window': 608, 'smoothing_window': 79}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,373] Trial 941 finished with value: 0.9788764232729092 and parameters: {'short_window': 95, 'long_window': 577, 'smoothing_window': 88}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,399] Trial 942 finished with value: 0.9960585040649917 and parameters: {'short_window': 98, 'long_window': 590, 'smoothing_window': 67}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,426] Trial 943 finished with value: 0.9944306615183499 and parameters: {'short_window': 96, 'long_window': 662, 'smoothing_window': 70}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,453] Trial 944 finished with value: 0.9944306615183499 and parameters: {'short_window': 100, 'long_window': 624, 'smoothing_window': 108}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,479] Trial 945 finished with value: 0.9793519279735756 and parameters: {'short_window': 75, 'long_window': 535, 'smoothing_window': 83}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,505] Trial 946 finished with value: 0.9949745100870802 and parameters: {'short_window': 90, 'long_window': 909, 'smoothing_window': 75}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,531] Trial 947 finished with value: 0.9966019075041972 and parameters: {'short_window': 94, 'long_window': 648, 'smoothing_window': 81}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,558] Trial 948 finished with value: 0.9966019075041972 and parameters: {'short_window': 98, 'long_window': 599, 'smoothing_window': 92}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,617] Trial 949 finished with value: 0.9719257697637204 and parameters: {'short_window': 9, 'long_window': 518, 'smoothing_window': 66}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,645] Trial 950 finished with value: 0.9966019075041972 and parameters: {'short_window': 97, 'long_window': 617, 'smoothing_window': 89}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,670] Trial 951 finished with value: 0.9960585040649917 and parameters: {'short_window': 100, 'long_window': 568, 'smoothing_window': 73}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,697] Trial 952 finished with value: 0.9944306615183499 and parameters: {'short_window': 92, 'long_window': 677, 'smoothing_window': 84}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,724] Trial 953 finished with value: 0.9966019075041972 and parameters: {'short_window': 96, 'long_window': 636, 'smoothing_window': 77}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,749] Trial 954 finished with value: 0.9966019075041972 and parameters: {'short_window': 98, 'long_window': 605, 'smoothing_window': 87}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,776] Trial 955 finished with value: 0.9788764232729092 and parameters: {'short_window': 94, 'long_window': 580, 'smoothing_window': 69}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,802] Trial 956 finished with value: 0.9944306615183499 and parameters: {'short_window': 99, 'long_window': 626, 'smoothing_window': 60}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,829] Trial 957 finished with value: 0.9944306615183499 and parameters: {'short_window': 96, 'long_window': 652, 'smoothing_window': 63}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,865] Trial 958 finished with value: 0.9966019075041972 and parameters: {'short_window': 100, 'long_window': 611, 'smoothing_window': 71}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,891] Trial 959 finished with value: 0.9960585040649917 and parameters: {'short_window': 98, 'long_window': 588, 'smoothing_window': 80}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,917] Trial 960 finished with value: 0.9514904362766954 and parameters: {'short_window': 36, 'long_window': 530, 'smoothing_window': 75}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,945] Trial 961 finished with value: 0.9966019075041972 and parameters: {'short_window': 94, 'long_window': 639, 'smoothing_window': 84}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,971] Trial 962 finished with value: 0.9788764232729092 and parameters: {'short_window': 97, 'long_window': 564, 'smoothing_window': 66}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:15,997] Trial 963 finished with value: 0.9966019075041972 and parameters: {'short_window': 92, 'long_window': 665, 'smoothing_window': 86}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,024] Trial 964 finished with value: 0.9960604304255098 and parameters: {'short_window': 95, 'long_window': 695, 'smoothing_window': 111}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,050] Trial 965 finished with value: 0.9966019075041972 and parameters: {'short_window': 100, 'long_window': 602, 'smoothing_window': 78}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,077] Trial 966 finished with value: 0.9966019075041972 and parameters: {'short_window': 98, 'long_window': 624, 'smoothing_window': 73}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,103] Trial 967 finished with value: 0.9885060409422275 and parameters: {'short_window': 96, 'long_window': 594, 'smoothing_window': 82}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,139] Trial 968 finished with value: 0.9966019075041972 and parameters: {'short_window': 98, 'long_window': 617, 'smoothing_window': 71}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,165] Trial 969 finished with value: 0.9826044972093372 and parameters: {'short_window': 89, 'long_window': 652, 'smoothing_window': 94}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,193] Trial 970 finished with value: 0.9944306615183499 and parameters: {'short_window': 100, 'long_window': 638, 'smoothing_window': 90}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,219] Trial 971 finished with value: 0.9799538511009666 and parameters: {'short_window': 93, 'long_window': 582, 'smoothing_window': 68}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,246] Trial 972 finished with value: 0.9960585040649917 and parameters: {'short_window': 96, 'long_window': 608, 'smoothing_window': 64}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,273] Trial 973 finished with value: 0.9966019075041972 and parameters: {'short_window': 98, 'long_window': 628, 'smoothing_window': 85}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,299] Trial 974 finished with value: 0.9944306615183499 and parameters: {'short_window': 95, 'long_window': 679, 'smoothing_window': 76}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,326] Trial 975 finished with value: 0.9966019075041972 and parameters: {'short_window': 100, 'long_window': 592, 'smoothing_window': 88}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,363] Trial 976 finished with value: 0.9966019075041972 and parameters: {'short_window': 97, 'long_window': 614, 'smoothing_window': 80}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,390] Trial 977 finished with value: 0.9810129650248667 and parameters: {'short_window': 91, 'long_window': 568, 'smoothing_window': 83}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,417] Trial 978 finished with value: 0.9966019075041972 and parameters: {'short_window': 94, 'long_window': 652, 'smoothing_window': 104}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,443] Trial 979 finished with value: 0.9944306615183499 and parameters: {'short_window': 99, 'long_window': 628, 'smoothing_window': 97}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,469] Trial 980 finished with value: 0.9794067009845915 and parameters: {'short_window': 66, 'long_window': 709, 'smoothing_window': 69}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,496] Trial 981 finished with value: 0.9966019075041972 and parameters: {'short_window': 97, 'long_window': 604, 'smoothing_window': 72}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,524] Trial 982 finished with value: 0.9944306615183499 and parameters: {'short_window': 95, 'long_window': 671, 'smoothing_window': 87}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,551] Trial 983 finished with value: 0.9944306615183499 and parameters: {'short_window': 100, 'long_window': 640, 'smoothing_window': 74}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,578] Trial 984 finished with value: 0.9960585040649917 and parameters: {'short_window': 98, 'long_window': 594, 'smoothing_window': 66}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,614] Trial 985 finished with value: 0.9799451958112351 and parameters: {'short_window': 93, 'long_window': 555, 'smoothing_window': 79}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,642] Trial 986 finished with value: 0.9966019075041972 and parameters: {'short_window': 96, 'long_window': 618, 'smoothing_window': 92}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,694] Trial 987 finished with value: 0.9890419618101831 and parameters: {'short_window': 98, 'long_window': 579, 'smoothing_window': 85}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,721] Trial 988 finished with value: 0.9944306615183499 and parameters: {'short_window': 100, 'long_window': 638, 'smoothing_window': 70}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,748] Trial 989 finished with value: 0.9966019075041972 and parameters: {'short_window': 96, 'long_window': 609, 'smoothing_window': 82}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,776] Trial 990 finished with value: 0.9966019075041972 and parameters: {'short_window': 93, 'long_window': 665, 'smoothing_window': 68}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,803] Trial 991 finished with value: 0.9960585040649917 and parameters: {'short_window': 98, 'long_window': 590, 'smoothing_window': 89}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,830] Trial 992 finished with value: 0.9944306615183499 and parameters: {'short_window': 95, 'long_window': 655, 'smoothing_window': 76}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,858] Trial 993 finished with value: 0.9944306615183499 and parameters: {'short_window': 100, 'long_window': 627, 'smoothing_window': 73}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,894] Trial 994 finished with value: 0.9820639436229562 and parameters: {'short_window': 91, 'long_window': 559, 'smoothing_window': 64}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,926] Trial 995 finished with value: 0.9966019075041972 and parameters: {'short_window': 97, 'long_window': 607, 'smoothing_window': 86}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,957] Trial 996 finished with value: 0.9863553614949783 and parameters: {'short_window': 98, 'long_window': 574, 'smoothing_window': 83}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:16,984] Trial 997 finished with value: 0.9901181867722649 and parameters: {'short_window': 88, 'long_window': 689, 'smoothing_window': 71}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:17,012] Trial 998 finished with value: 0.9966019075041972 and parameters: {'short_window': 94, 'long_window': 642, 'smoothing_window': 78}. Best is trial 10 with value: 0.9966019075041972.
# [I 2025-04-07 21:13:17,039] Trial 999 finished with value: 0.9938897737973454 and parameters: {'short_window': 100, 'long_window': 976, 'smoothing_window': 61}. Best is trial 10 with value: 0.9966019075041972.
# Best Parameters: {'short_window': 99, 'long_window': 603, 'smoothing_window': 75}
# Final Equity Multiplier: 1.00x
